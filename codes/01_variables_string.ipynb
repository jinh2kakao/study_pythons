# %%
first = "welcome jinhyun."

print(first)
# Out:
# welcome jinhyun.

# %%
first
# Out:
# 'welcome jinhyun.'

# %%
first = 'good day!'

# %%
second = "Life is simple 'realy?'"

# %%
first = second

# %%
first
# Out:
# "Life is simple 'realy?'"

# %%
third = "Life is simple!" + ' ' + 'Good!!'

# %%
third = first + " " + second

# %%
third
# Out:
# "Life is simple 'realy?' Life is simple 'realy?'"

# %% [markdown]
# ## 문제 풀이
# - 두 문자열 변수를 선언해서 각각 변수에 값을 넣고, +기호를 이용해 이어서 문자열을 작성해보세요.
# - 변수 이름: first, second, result
# - 결과: 'Good Mornin!

# %%
first = "Good"

# %%
second = "Morning!"

# %%
result = first + " " + second

print(result)
# Out:
# Good Morning!
