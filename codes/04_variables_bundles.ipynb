# %%
car_01 = {
    "no":1,
    "Brand":"Toyota",
    "Model":"Corolla",
    "Color":"Red"
}

# %%
car_02 = {
    "no":2,
    "Brand":"Honda",
    "Model":"Civic",
    "Color":"Black"
}

# %%
car_03 = {
    "no":3,
    "Brand":"BMW",
    "Model":"X5",
    "Color":"White"
}

# %%
car_information_list = [
    car_01,
    car_02,
    car_03
]

# %%
 car_information_dict = [
    {
        "no":1,
        "Brand":"Toyota",
        "Model":"Corolla",
        "Color":"Red"
    },
    {
        "no":2,
        "Brand":"Honda",
        "Model":"Civic",
        "Color":"Black"
    },
    {
        "no":3,
        "Brand":"BMW",
        "Model":"X5",
        "Color":"White"
    }
]

# print(car_information_list[0])

# %%
# 딕셔너리에서 특정값 확인
# car_information_dict[1]["Model"]
car_information_dict[1]["Brand"]
# Out:
# 'Honda'

# %% [markdown]
# # 문제풀이

# %% [markdown]
# ### 문제 1. 리스트 만들기
# 회사원 이름을 순서대로 리스트에 저장해 보세요.
#  리스트 이름: employees
# 번호
# 이름
# 1
# Alice
# 2
# Bob
# 3
# Charlie
# 4
# Diana
#
# # employees 리스트를 만들어 보세요
# # Alice 출력
# # Charlie 출력

# %%
employees = [
    {
        "no":1,
        "name":"Alice"
    },
    {
        "no":2,
        "name":"Bob"
    },
    {
        "no":3,
        "name":"Charlie"
    },
    {
        "no":4,
        "name":"Diana"
    }
]

print(employees[0]["name"])
print(employees[2]["name"])
# Out:
# Alice
# Charlie

# %% [markdown]
# ### 문제 2. 딕셔너리 만들기
# 한 명의 회사원 정보를 딕셔너리로 만들어 보세요.
#  딕셔너리 이름: employee1
# - 키, 값
# - name, Alice
# - department, Sales
# - position, Manager
# - year, 2023
#
# # employee1 딕셔너리를 만들어 보세요
# # “Manager” 를 출력

# %%
employee1 = {
    "name":"Alice",
    "department":"Sales",
    "position":"Manager",
    "year":2023
}

print(employee1["position"])
# Out:
# Manager

# %% [markdown]
# ### 문제 3. 리스트 안 딕셔너리 만들기
# 여러 회사원의 정보를 리스트 안 딕셔너리 형태로 만들어 보세요.
#  리스트 이름: all_employees
#  # all_employees 리스트 안에 딕셔너리를 만들어 보세요
#
#  - name , department, position, year
# - Alice, Sales, Manager, 2023
# - Bob, IT, Engineer, 2022
# - Charlie, HR, Staff, 2023
# - Diana, Marketing, Analyst, 2024
#
# # 3 번째 직원 정보 출력
# # 2 번째 position 출력

# %%
all_employees = [
    {"no":1, "name":"Alice", "department":"Sales", "position":"Manager", "year":2023},
    {"no":2, "name":"Bob", "department":"IT", "position":"Engineer", "year":2022},
    {"no":3, "name":"IT", "department":"HR", "position":"Staff", "year":2023},
    {"no":4, "name":"Diana", "department":"Marketing", "position":"Analyst", "year":2024}
]
print(all_employees[2])
print(all_employees[1]["position"])
# Out:
# {'no': 3, 'name': 'IT', 'department': 'HR', 'position': 'Staff', 'year': 2023}
# Engineer
